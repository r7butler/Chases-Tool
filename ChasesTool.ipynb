# %% [markdown]
# # This is the code we are using to re-create chase's tool for the infauna data

# %% [markdown]
# First we import the necessary packages

# %%
import pandas as pd
from sqlalchemy import create_engine
import numpy as np

# %% [markdown]
# Then read in the raw data and prepare it

# %%
initial = pd.read_excel("data/Infauna_QC_B13_OCSD.xlsm", sheet_name = 'Original_Data')
qc = pd.read_excel("data/Infauna_QC_B13_OCSD.xlsm", sheet_name = 'QC_Data')
qc.rename(columns={" SITE": "SITE"}, inplace=True)

# %% [markdown]
# Here we build the dataframe that will become the discrepancy report by merging the initial and QC dataframes

# %%
output = pd.merge(initial, qc, left_on = ['SITE', 'ORIGINAL SPECIES'], right_on = ['SITE', 'QC SPECIES'], how = 'outer')
output = output[['SITE', 'ORIGINAL SPECIES', 'ORIGINAL ABUNDANCE', 'ORIGINAL VOUCHER', 'QC SPECIES', 'QC ABUNDANCE']]

# %% [markdown]
# The next two lines add the columns stating whether or not there is a match, and the type of discrepancy

# %%
output['Match/Not Match'] = output.apply(lambda x: 'Match' if ((x['ORIGINAL SPECIES'] != x['QC SPECIES']) & (x['ORIGINAL ABUNDANCE'] == x['QC ABUNDANCE'])) else 'No Match', axis=1)

# %%
output['Type'] = output.apply(lambda x: 'ID' if (x['ORIGINAL SPECIES'] != x['QC SPECIES']) else 'Count' if (x['ORIGINAL ABUNDANCE'] != x['QC ABUNDANCE']) else np.nan, axis = 1)

# %% [markdown]
# This next cell is purely for cosmetic purposes

# %%
output.sort_values(['SITE', 'Match/Not Match', 'ORIGINAL SPECIES', 'QC SPECIES'], inplace=True)
output.reset_index(inplace=True)
output.drop("index", axis=1, inplace=True)

# %% [markdown]
# And here are the dataframes, the initial, the QC data, and the output

# %%
initial.head()
# Out:
#                 ORIGINAL SPECIES  ORIGINAL ABUNDANCE  ORIGINAL VOUCHER  \
# 0                 Theora lubrica                   7               NaN
# 1              Psammotreta obesa                   1               NaN
# 2               Leukoma staminea                   5               NaN
# 3          Chione californiensis                   2               NaN
# 4            Caecum californicum                   1               NaN
# 5                Bulla gouldiana                   1               NaN
# 6             Acteocina carinata                   4               NaN
# 7                   Nicolea sp A                   1               1.0
# 8             Diplocirrus sp SD1                   1               NaN
# 9               Tubulanus sp SD1                   1               1.0
# 10         Edwardsia californica                  86               5.0
# 11       Pseudotanais makrothrix                   1               1.0
# 12           Paranthura japonica                   1               NaN
# 13         Mayerella acanthopoda                   3               NaN
# 14              Eochelidium sp A                   1               NaN
# 15             Euchone limnicola                 146               NaN
# 16      Ericthonius brasiliensis                  47               NaN
# 17                  Edwardsiidae                  11               NaN
# 18              Edwardsia juliae                   7               NaN
# 19          Musculista senhousia                   3               NaN
# 20        Crepipatella lingulata                   1               NaN
# 21                  Cossura sp A                   1               NaN
# 22                  Corophioidea                   2               NaN
# 23        Cooperella subdiaphana                   4               NaN
# 24                  Cirratulidae                   1               NaN
# 25                    Sabellidae                   2               NaN
# 26   Acuminodeutopus heteruropus                   4               NaN
# 27                      Copepoda                   2               NaN
# 28                      Bivalvia                   1               NaN
# 29               Armandia brevis                  22               NaN
# ..                           ...                 ...               ...
# 271           Nephtys ferruginea                   1               NaN
# 272            Nephtys caecoides                   2               NaN
# 273              Nebalia daytoni                   1               1.0
# 274         Monticellina siblina                   4               NaN
# 275              Amphioplus sp A                   2               NaN
# 276        Monticellina cryptica                   2               NaN
# 277              Amphiodia psara                   3               1.0
# 278               Mediomastus sp                  24               NaN
# 279         Malmgreniella baschi                   6               NaN
# 280           Magelona sacculata                   1               NaN
# 281           Magelona berkeleyi                  10               NaN
# 282           Macoma yoldiformis                   3               NaN
# 283         Lumbrineris japonica                   1               NaN
# 284      Leptochelia dubia Cmplx                   1               NaN
# 285   Leitoscoloplos pugettensis                   2               NaN
# 286                Kurtzina beta                   1               NaN
# 287               Heteronemertea                   1               NaN
# 288  Ampelisca cristata cristata                   5               NaN
# 289           Ampelisca agassizi                   4               NaN
# 290             Goniada maculata                   4               NaN
# 291            Glycinde armigera                   1               NaN
# 292                 Glycera nana                   2               NaN
# 293            Glycera americana                   1               NaN
# 294             Glottidia albida                   1               NaN
# 295        Gammaropsis thompsoni                   1               NaN
# 296              Gadila aberrans                   8               NaN
# 297        Foxiphalus obtusidens                   1               NaN
# 298               Exogone lourei                   1               NaN
# 299               Alvania rosana                   1               NaN
# 300   Euphilomedes carcharodonta                   2               NaN
#
#          SITE
# 0    B13-8328
# 1    B13-8328
# 2    B13-8328
# 3    B13-8328
# 4    B13-8328
# 5    B13-8328
# 6    B13-8328
# 7    B13-8328
# 8    B13-8328
# 9    B13-8328
# 10   B13-8328
# 11   B13-8328
# 12   B13-8328
# 13   B13-8328
# 14   B13-8328
# 15   B13-8328
# 16   B13-8328
# 17   B13-8328
# 18   B13-8328
# 19   B13-8328
# 20   B13-8328
# 21   B13-8328
# 22   B13-8328
# 23   B13-8328
# 24   B13-8328
# 25   B13-8328
# 26   B13-8328
# 27   B13-8328
# 28   B13-8328
# 29   B13-8328
# ..        ...
# 271  B13-9481
# 272  B13-9481
# 273  B13-9481
# 274  B13-9481
# 275  B13-9481
# 276  B13-9481
# 277  B13-9481
# 278  B13-9481
# 279  B13-9481
# 280  B13-9481
# 281  B13-9481
# 282  B13-9481
# 283  B13-9481
# 284  B13-9481
# 285  B13-9481
# 286  B13-9481
# 287  B13-9481
# 288  B13-9481
# 289  B13-9481
# 290  B13-9481
# 291  B13-9481
# 292  B13-9481
# 293  B13-9481
# 294  B13-9481
# 295  B13-9481
# 296  B13-9481
# 297  B13-9481
# 298  B13-9481
# 299  B13-9481
# 300  B13-9481
#
# [301 rows x 4 columns]

# %%
qc.head()
# Out:
#                                  QC SPECIES  QC ABUNDANCE      SITE
# 0                       Protomima imitatrix            42  B13-8328
# 1        Scolelepis (Parascolelepis) texana             1  B13-8328
# 2               Rudilemboides stenopropodus            18  B13-8328
# 3                         Psammotreta obesa             1  B13-8328
# 4            Pseudopolydora paucibranchiata            11  B13-8328
# 5    Prionospio (Prionospio) heterobranchia             4  B13-8328
# 6                             Polycirrus sp             1  B13-8328
# 7                Prionospio (Prionospio) sp             2  B13-8328
# 8              Sphaerosyllis californiensis             2  B13-8328
# 9                            Scoletoma sp B             1  B13-8328
# 10                        Spiophanes duplex            20  B13-8328
# 11                            Spiophanes sp             2  B13-8328
# 12                               Tagelus sp             8  B13-8328
# 13                    Tubulanus polymorphus             2  B13-8328
# 14                             Tergipedidae             1  B13-8328
# 15                               Veneroidea             5  B13-8328
# 16                         Tubulanus sp SD1             1  B13-8328
# 17                                 Venerida             1  B13-8328
# 18                            Zeuxo normani             1  B13-8328
# 19                   Zygonemertes virescens             2  B13-8328
# 20                     Monticellina siblina             3  B13-8328
# 21                     Musculista senhousia             4  B13-8328
# 22                      Megalomma pigmentum            42  B13-8328
# 23                           Mediomastus sp            24  B13-8328
# 24                          Melinna oculata             1  B13-8328
# 25                     Microspio pigmentata             1  B13-8328
# 26                           Molgula sp SD1            38  B13-8328
# 27                           Notodelphyidae             2  B13-8328
# 28                     Postasterope barnesi             3  B13-8328
# 29                                 Pista sp             6  B13-8328
# ..                                      ...           ...       ...
# 232                           Virgulariidae             1  B13-9481
# 233                          Tubulanus sp A             1  B13-9481
# 234                   Tubulanus polymorphus             1  B13-9481
# 235                            Scoloplos sp             3  B13-9481
# 236                      Spiophanes norrisi             1  B13-9481
# 237         Spiochaetopterus costarum Cmplx             7  B13-9481
# 238                       Spiophanes duplex             1  B13-9481
# 239          Prionospio (Prionospio) jubata             2  B13-9481
# 240                Rhepoxynius bicuspidatus             7  B13-9481
# 241                    Rhepoxynius menziesi             2  B13-9481
# 242                            Rutiderma sp             1  B13-9481
# 243                    Rhepoxynius stenodes            12  B13-9481
# 244                    Rhepoxynius variatus            22  B13-9481
# 245                    Monticellina siblina             5  B13-9481
# 246                       Nephtys caecoides             2  B13-9481
# 247                   Monticellina cryptica             2  B13-9481
# 248                            Opiura sarsi             1  B13-9481
# 249                            Onuphis sp A             1  B13-9481
# 250                      Nephtys ferruginea             1  B13-9481
# 251                        Nuculana taphria             3  B13-9481
# 252                    Paraprionospio alata             1  B13-9481
# 253                Paranemertes californica             1  B13-9481
# 254                Parvilucina tenuisculpta             1  B13-9481
# 255               Pectinaria californiensis             1  B13-9481
# 256                           Pholoe glabra             9  B13-9481
# 257                               Pista wui             2  B13-9481
# 258                    Podarkeopsis glabrus             1  B13-9481
# 259                 Poecilochaetus johnsoni             6  B13-9481
# 260            Prionospio (Minuspio) lighti            43  B13-9481
# 261                           Pinnotheridae             2  B13-9481
#
# [262 rows x 3 columns]

# %% [markdown]
# Below is the final output from our re-creation of Chase's tool. You can view the whole thing by clicking on DiscrepancyReport.csv

# %%
output.head()
# Out:
#          SITE                 ORIGINAL SPECIES  ORIGINAL ABUNDANCE  \
# 0    B13-8328                       ARTHROPODA                 2.0
# 1    B13-8328               Acteocina carinata                 4.0
# 2    B13-8328      Acuminodeutopus heteruropus                 4.0
# 3    B13-8328           Ampelisca brachycladus                 1.0
# 4    B13-8328                Ampharete labrops                 2.0
# 5    B13-8328      Amphicteis scaphobranchiata                 1.0
# 6    B13-8328           Amphideutopus oculatus               101.0
# 7    B13-8328               Amphiodia digitata                 2.0
# 8    B13-8328             Amphipholis squamata                 6.0
# 9    B13-8328           Anoplodactylus erectus                 1.0
# 10   B13-8328             Apionsoma misakianum                 1.0
# 11   B13-8328            Apoprionospio pygmaea                 1.0
# 12   B13-8328           Argopecten ventricosus                 1.0
# 13   B13-8328                  Armandia brevis                22.0
# 14   B13-8328           Bipalponephtys cornuta                 1.0
# 15   B13-8328                         Bivalvia                 1.0
# 16   B13-8328                  Bulla gouldiana                 1.0
# 17   B13-8328              Caecum californicum                 1.0
# 18   B13-8328          Cerebratulus marginatus                 1.0
# 19   B13-8328            Chione californiensis                 2.0
# 20   B13-8328             Chrysallida eucosmia                 1.0
# 21   B13-8328                     Cirratulidae                 1.0
# 22   B13-8328           Cooperella subdiaphana                 4.0
# 23   B13-8328                         Copepoda                 2.0
# 24   B13-8328                     Corophioidea                 2.0
# 25   B13-8328                     Cossura sp A                 1.0
# 26   B13-8328           Crepipatella lingulata                 1.0
# 27   B13-8328               Diplocirrus sp SD1                 1.0
# 28   B13-8328            Edwardsia californica                86.0
# 29   B13-8328                 Edwardsia juliae                 7.0
# ..        ...                              ...                 ...
# 353  B13-9481             Rhepoxynius menziesi                 3.0
# 354  B13-9481             Rhepoxynius stenodes                12.0
# 355  B13-9481             Rhepoxynius variatus                47.0
# 356  B13-9481              Rutiderma rostratum                 1.0
# 357  B13-9481               Scoloplos acmeceps                 1.0
# 358  B13-9481                 Sinum scopulosum                 1.0
# 359  B13-9481  Spiochaetopterus costarum Cmplx                 7.0
# 360  B13-9481                Spiophanes duplex                 1.0
# 361  B13-9481               Spiophanes norrisi                 1.0
# 362  B13-9481                  Tellina modesta                17.0
# 363  B13-9481            Tubulanus polymorphus                 2.0
# 364  B13-9481              Volvulella panamica                 1.0
# 365  B13-9481                Westwoodilla tone                 1.0
# 366  B13-9481                              NaN                 NaN
# 367  B13-9481                              NaN                 NaN
# 368  B13-9481                              NaN                 NaN
# 369  B13-9481                              NaN                 NaN
# 370  B13-9481                              NaN                 NaN
# 371  B13-9481                              NaN                 NaN
# 372  B13-9481                              NaN                 NaN
# 373  B13-9481                              NaN                 NaN
# 374  B13-9481                              NaN                 NaN
# 375  B13-9481                              NaN                 NaN
# 376  B13-9481                              NaN                 NaN
# 377  B13-9481                              NaN                 NaN
# 378  B13-9481                              NaN                 NaN
# 379  B13-9481                              NaN                 NaN
# 380  B13-9481                              NaN                 NaN
# 381  B13-9481                              NaN                 NaN
# 382  B13-9481                              NaN                 NaN
#
#      ORIGINAL VOUCHER                       QC SPECIES  QC ABUNDANCE  \
# 0                 NaN                              NaN           NaN
# 1                 NaN                              NaN           NaN
# 2                 NaN                              NaN           NaN
# 3                 NaN                              NaN           NaN
# 4                 NaN                              NaN           NaN
# 5                 NaN      Amphicteis scaphobranchiata           1.0
# 6                 NaN           Amphideutopus oculatus         105.0
# 7                 NaN               Amphiodia digitata           1.0
# 8                 NaN             Amphipholis squamata           6.0
# 9                 NaN           Anoplodactylus erectus           1.0
# 10                NaN             Apionsoma misakianum           2.0
# 11                NaN                              NaN           NaN
# 12                NaN                              NaN           NaN
# 13                NaN                  Armandia brevis          21.0
# 14                NaN           Bipalponephtys cornuta           1.0
# 15                NaN                              NaN           NaN
# 16                NaN                  Bulla gouldiana           1.0
# 17                NaN              Caecum californicum           1.0
# 18                NaN                              NaN           NaN
# 19                NaN            Chione californiensis           9.0
# 20                1.0                              NaN           NaN
# 21                NaN                              NaN           NaN
# 22                NaN           Cooperella subdiaphana           2.0
# 23                NaN                              NaN           NaN
# 24                NaN                              NaN           NaN
# 25                NaN                              NaN           NaN
# 26                NaN                              NaN           NaN
# 27                NaN                              NaN           NaN
# 28                5.0            Edwardsia californica          96.0
# 29                NaN                              NaN           NaN
# ..                ...                              ...           ...
# 353               NaN             Rhepoxynius menziesi           2.0
# 354               NaN             Rhepoxynius stenodes          12.0
# 355              21.0             Rhepoxynius variatus          22.0
# 356               NaN                              NaN           NaN
# 357               NaN                              NaN           NaN
# 358               1.0                              NaN           NaN
# 359               NaN  Spiochaetopterus costarum Cmplx           7.0
# 360               NaN                Spiophanes duplex           1.0
# 361               NaN               Spiophanes norrisi           1.0
# 362               NaN                  Tellina modesta          17.0
# 363               NaN            Tubulanus polymorphus           1.0
# 364               NaN              Volvulella panamica           1.0
# 365               NaN                Westwoodilla tone           1.0
# 366               NaN                 Alvania compacta           1.0
# 367               NaN               Amphiodia digitata           3.0
# 368               NaN                     Amphiodia sp           1.0
# 369               NaN                      Amphiuridae           2.0
# 370               NaN                Chaetozone sp SD3           2.0
# 371               NaN                       Glycera sp           2.0
# 372               NaN                  Hinea insculpta           1.0
# 373               NaN                        Macoma sp           3.0
# 374               NaN        Malmgreniella macginitiei           6.0
# 375               NaN                     Opiura sarsi           1.0
# 376               NaN                    Pinnotheridae           2.0
# 377               NaN             Podarkeopsis glabrus           1.0
# 378               NaN                     Rutiderma sp           1.0
# 379               NaN                     Scoloplos sp           3.0
# 380               NaN                   Tubulanus sp A           1.0
# 381               NaN                    Virgulariidae           1.0
# 382               NaN                Zygeupolia rubens           1.0
#
#     Match/Not Match   Type
# 0          No Match     ID
# 1          No Match     ID
# 2          No Match     ID
# 3          No Match     ID
# 4          No Match     ID
# 5          No Match    NaN
# 6          No Match  Count
# 7          No Match  Count
# 8          No Match    NaN
# 9          No Match    NaN
# 10         No Match  Count
# 11         No Match     ID
# 12         No Match     ID
# 13         No Match  Count
# 14         No Match    NaN
# 15         No Match     ID
# 16         No Match    NaN
# 17         No Match    NaN
# 18         No Match     ID
# 19         No Match  Count
# 20         No Match     ID
# 21         No Match     ID
# 22         No Match  Count
# 23         No Match     ID
# 24         No Match     ID
# 25         No Match     ID
# 26         No Match     ID
# 27         No Match     ID
# 28         No Match  Count
# 29         No Match     ID
# ..              ...    ...
# 353        No Match  Count
# 354        No Match    NaN
# 355        No Match  Count
# 356        No Match     ID
# 357        No Match     ID
# 358        No Match     ID
# 359        No Match    NaN
# 360        No Match    NaN
# 361        No Match    NaN
# 362        No Match    NaN
# 363        No Match  Count
# 364        No Match    NaN
# 365        No Match    NaN
# 366        No Match     ID
# 367        No Match     ID
# 368        No Match     ID
# 369        No Match     ID
# 370        No Match     ID
# 371        No Match     ID
# 372        No Match     ID
# 373        No Match     ID
# 374        No Match     ID
# 375        No Match     ID
# 376        No Match     ID
# 377        No Match     ID
# 378        No Match     ID
# 379        No Match     ID
# 380        No Match     ID
# 381        No Match     ID
# 382        No Match     ID
#
# [383 rows x 8 columns]
