# %% [markdown]
# # This is the code we are using to re-create chase's tool for the infauna data

# %% [markdown]
# First we import the necessary packages

# %%
import pandas as pd
from sqlalchemy import create_engine
import numpy as np

# %% [markdown]
# Then read in the raw data and prepare it

# %%
initial = pd.read_excel("data/Infauna_QC_B13_OCSD.xlsm", sheet_name = 'Original_Data')
qc = pd.read_excel("data/Infauna_QC_B13_OCSD.xlsm", sheet_name = 'QC_Data')
qc.rename(columns={" SITE": "SITE"}, inplace=True)

# %% [markdown]
# Here we build the dataframe that will become the discrepancy report by merging the initial and QC dataframes

# %%
output = pd.merge(initial, qc, left_on = ['SITE', 'ORIGINAL SPECIES'], right_on = ['SITE', 'QC SPECIES'], how = 'outer')
output = output[['SITE', 'ORIGINAL SPECIES', 'ORIGINAL ABUNDANCE', 'ORIGINAL VOUCHER', 'QC SPECIES', 'QC ABUNDANCE']]

# %% [markdown]
# The next two lines add the columns stating whether or not there is a match, and the type of discrepancy

# %%
output['Match/Not Match'] = output.apply(lambda x: 'Match' if ((x['ORIGINAL SPECIES'] != x['QC SPECIES']) & (x['ORIGINAL ABUNDANCE'] == x['QC ABUNDANCE'])) else 'No Match', axis=1)

# %%
output['Type'] = output.apply(lambda x: 'ID' if (x['ORIGINAL SPECIES'] != x['QC SPECIES']) else 'Count' if (x['ORIGINAL ABUNDANCE'] != x['QC ABUNDANCE']) else np.nan, axis = 1)

# %% [markdown]
# This next cell is purely for cosmetic purposes

# %%
output.sort_values(['SITE', 'Match/Not Match', 'ORIGINAL SPECIES', 'QC SPECIES'], inplace=True)
output.reset_index(inplace=True)
output.drop("index", axis=1, inplace=True)

# %% [markdown]
# And here are the dataframes, the initial, the QC data, and the output. I have posted them in the repository as csv files so that you can click on them and view the full thing. Here, only the first 15 lines are displayed.

# %%
initial.head(15)
# Out:
#            ORIGINAL SPECIES  ORIGINAL ABUNDANCE  ORIGINAL VOUCHER      SITE
# 0            Theora lubrica                   7               NaN  B13-8328
# 1         Psammotreta obesa                   1               NaN  B13-8328
# 2          Leukoma staminea                   5               NaN  B13-8328
# 3     Chione californiensis                   2               NaN  B13-8328
# 4       Caecum californicum                   1               NaN  B13-8328
# 5           Bulla gouldiana                   1               NaN  B13-8328
# 6        Acteocina carinata                   4               NaN  B13-8328
# 7              Nicolea sp A                   1               1.0  B13-8328
# 8        Diplocirrus sp SD1                   1               NaN  B13-8328
# 9          Tubulanus sp SD1                   1               1.0  B13-8328
# 10    Edwardsia californica                  86               5.0  B13-8328
# 11  Pseudotanais makrothrix                   1               1.0  B13-8328
# 12      Paranthura japonica                   1               NaN  B13-8328
# 13    Mayerella acanthopoda                   3               NaN  B13-8328
# 14         Eochelidium sp A                   1               NaN  B13-8328

# %%
qc.head(15)
# Out:
#                                 QC SPECIES  QC ABUNDANCE      SITE
# 0                      Protomima imitatrix            42  B13-8328
# 1       Scolelepis (Parascolelepis) texana             1  B13-8328
# 2              Rudilemboides stenopropodus            18  B13-8328
# 3                        Psammotreta obesa             1  B13-8328
# 4           Pseudopolydora paucibranchiata            11  B13-8328
# 5   Prionospio (Prionospio) heterobranchia             4  B13-8328
# 6                            Polycirrus sp             1  B13-8328
# 7               Prionospio (Prionospio) sp             2  B13-8328
# 8             Sphaerosyllis californiensis             2  B13-8328
# 9                           Scoletoma sp B             1  B13-8328
# 10                       Spiophanes duplex            20  B13-8328
# 11                           Spiophanes sp             2  B13-8328
# 12                              Tagelus sp             8  B13-8328
# 13                   Tubulanus polymorphus             2  B13-8328
# 14                            Tergipedidae             1  B13-8328

# %%
output.head(15)
# Out:
#         SITE             ORIGINAL SPECIES  ORIGINAL ABUNDANCE  \
# 0   B13-8328                   ARTHROPODA                 2.0
# 1   B13-8328           Acteocina carinata                 4.0
# 2   B13-8328  Acuminodeutopus heteruropus                 4.0
# 3   B13-8328       Ampelisca brachycladus                 1.0
# 4   B13-8328            Ampharete labrops                 2.0
# 5   B13-8328  Amphicteis scaphobranchiata                 1.0
# 6   B13-8328       Amphideutopus oculatus               101.0
# 7   B13-8328           Amphiodia digitata                 2.0
# 8   B13-8328         Amphipholis squamata                 6.0
# 9   B13-8328       Anoplodactylus erectus                 1.0
# 10  B13-8328         Apionsoma misakianum                 1.0
# 11  B13-8328        Apoprionospio pygmaea                 1.0
# 12  B13-8328       Argopecten ventricosus                 1.0
# 13  B13-8328              Armandia brevis                22.0
# 14  B13-8328       Bipalponephtys cornuta                 1.0
#
#     ORIGINAL VOUCHER                   QC SPECIES  QC ABUNDANCE  \
# 0                NaN                          NaN           NaN
# 1                NaN                          NaN           NaN
# 2                NaN                          NaN           NaN
# 3                NaN                          NaN           NaN
# 4                NaN                          NaN           NaN
# 5                NaN  Amphicteis scaphobranchiata           1.0
# 6                NaN       Amphideutopus oculatus         105.0
# 7                NaN           Amphiodia digitata           1.0
# 8                NaN         Amphipholis squamata           6.0
# 9                NaN       Anoplodactylus erectus           1.0
# 10               NaN         Apionsoma misakianum           2.0
# 11               NaN                          NaN           NaN
# 12               NaN                          NaN           NaN
# 13               NaN              Armandia brevis          21.0
# 14               NaN       Bipalponephtys cornuta           1.0
#
#    Match/Not Match   Type
# 0         No Match     ID
# 1         No Match     ID
# 2         No Match     ID
# 3         No Match     ID
# 4         No Match     ID
# 5         No Match    NaN
# 6         No Match  Count
# 7         No Match  Count
# 8         No Match    NaN
# 9         No Match    NaN
# 10        No Match  Count
# 11        No Match     ID
# 12        No Match     ID
# 13        No Match  Count
# 14        No Match    NaN
